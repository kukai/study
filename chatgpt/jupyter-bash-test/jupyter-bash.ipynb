# %% [markdown]
# # VSCode 上の jupyter notebook で bash を動かす検証
#
# - kernelを固定するには？
# - Markdown Cell のプレビューモードにするには？
#   - 編集モードを終われば良い
# - Cellをロックするには？

# %%
brew list | xargs -I{} sh -c 'brew uses --installed {} | wc -l | xargs printf "%20s is used by %2d formulae.\n" {}' | grep '0 formula'
# Out:
#                 asdf is used by  0 formulae.
#                  bat is used by  0 formulae.
#               docker is used by  0 formulae.
#             exiftool is used by  0 formulae.
#                  fzf is used by  0 formulae.
#                  ghq is used by  0 formulae.
#                  git is used by  0 formulae.
#              gnu-sed is used by  0 formulae.
#            handbrake is used by  0 formulae.
#                   jq is used by  0 formulae.
#                  mas is used by  0 formulae.
#                 peco is used by  0 formulae.
#                rsync is used by  0 formulae.
#                 tmux is used by  0 formulae.
#                 tree is used by  0 formulae.
#      universal-ctags is used by  0 formulae.
#                 wget is used by  0 formulae.
# Warning: No available formula with the name "1password".
#            1password is used by  0 formulae.
# Warning: No available formula with the name "ableton-live-lite".
#    ableton-live-lite is used by  0 formulae.
# Warning: No available formula with the name "appcleaner".
#           appcleaner is used by  0 formulae.
# Warning: No available formula with the name "bettertouchtool". Did you mean bettercap?
#      bettertouchtool is used by  0 formulae.
# Warning: No available formula with the name "coconutbattery".
#       coconutbattery is used by  0 formulae.
# Warning: No available formula with the name "cyberduck".
#            cyberduck is used by  0 formulae.
# Warning: No available formula with the name "deepl". Did you mean dep?
#                deepl is used by  0 formulae.
# Warning: No available formula with the name "diffusionbee". Did you mean diffutils?
#         diffusionbee is used by  0 formulae.
# Warning: No available formula with the name "discord". Did you mean discount?
#              discord is used by  0 formulae.
# Warning: No available formula with the name "ferdi". Did you mean pferd?
#                ferdi is used by  0 formulae.
# Warning: No available formula with the name "font-ricty-diminished".
# font-ricty-diminished is used by  0 formulae.
# Warning: No available formula with the name "fujitsu-scansnap-home".
# fujitsu-scansnap-home is used by  0 formulae.
# Warning: No available formula with the name "intellij-idea-ce".
#     intellij-idea-ce is used by  0 formulae.
# Warning: No available formula with the name "iterm2-beta".
#          iterm2-beta is used by  0 formulae.
# Warning: No available formula with the name "karabiner-elements".
#   karabiner-elements is used by  0 formulae.
# Warning: No available formula with the name "keyboard-cleaner".
#     keyboard-cleaner is used by  0 formulae.
# Warning: No available formula with the name "kindle". Did you mean kind?
#               kindle is used by  0 formulae.
# Warning: No available formula with the name "notion". Did you mean noti?
#               notion is used by  0 formulae.
# Warning: No available formula with the name "obsidian".
#             obsidian is used by  0 formulae.
# Warning: No available formula with the name "rancher". Did you mean ranger?
#              rancher is used by  0 formulae.
# Warning: No available formula with the name "raycast". Did you mean yacas?
#              raycast is used by  0 formulae.
# Warning: No available formula with the name "sdformatter". Did you mean pgformatter?
#          sdformatter is used by  0 formulae.
# Warning: No available formula with the name "sequel-ace".
#           sequel-ace is used by  0 formulae.
# Warning: No available formula with the name "splashtop-streamer".
#   splashtop-streamer is used by  0 formulae.
# Warning: No available formula with the name "spotify". Did you mean spotifyd, shpotify or gotify?
#              spotify is used by  0 formulae.
# Warning: No available formula with the name "sublime-text".
#         sublime-text is used by  0 formulae.
# Warning: No available formula with the name "vimr". Did you mean vim?
#                 vimr is used by  0 formulae.
# Warning: No available formula with the name "visual-studio-code".
#   visual-studio-code is used by  0 formulae.
# Warning: No available formula with the name "visualboyadvance-m".
#   visualboyadvance-m is used by  0 formulae.
# Warning: No available formula with the name "vlc".
#                  vlc is used by  0 formulae.
# Warning: No available formula with the name "warp". Did you mean wapm?
#                 warp is used by  0 formulae.
# Warning: No available formula with the name "wine-crossover". Did you mean wine-crossover@21, wine-crossover@20 or wine-crossover@19?
#       wine-crossover is used by  0 formulae.
