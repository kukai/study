# %% [markdown]
# # langchain agent - plan and execute
#
# ## 目的
# https://tech.algomatic.jp/entry/2024/03/19/183912 を参考に自律エージェントの作り方を学習する

# %% [markdown]
# ```
# langchain==0.1.12
# langchain_openai==0.0.8
# tavily-python==0.3.1
# langchainhub==0.1.15
# langgraph==0.0.28
# ```
#
# ```
# poetry install
# ```
